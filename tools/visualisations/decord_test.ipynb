# %%
import decord
decord.bridge.set_bridge('torch')
from decord import VideoReader, gpu

vr = VideoReader('/fast/kiyoon/datasets/something-something-v2/videos/13313.webm', gpu(0), num_threads=1)
print(len(vr))
print(vr.get_batch([15, 2, 32]))
# Out:
# ---------------------------------------------------------------------------
# DECORDError                               Traceback (most recent call last)
# <ipython-input-42-ec67250cfccd> in <module>
#       3 from decord import VideoReader, gpu
#       4
# ----> 5 vr = VideoReader('/fast/kiyoon/datasets/something-something-v2/videos/13313.webm', gpu(0), num_threads=1)
#       6 print(len(vr))
#       7 print(vr.get_batch([15, 2, 32]))
#
# ~/bin/miniconda3/envs/videoai/lib/python3.8/site-packages/decord/video_reader.py in __init__(self, uri, ctx, width, height, num_threads, fault_tol)
#      52                 ba, ctx.device_type, ctx.device_id, width, height, num_threads, 2, fault_tol)
#      53         else:
# ---> 54             self._handle = _CAPI_VideoReaderGetVideoReader(
#      55                 uri, ctx.device_type, ctx.device_id, width, height, num_threads, 0, fault_tol)
#      56         if self._handle is None:
#
# ...

# %%
import matplotlib.pyplot as plt
print(len(vr))
plt.imshow(vr[32])
# Out:
# 33

# %%
img1= vr.get_batch([31,32])
gr = img1[...,0]*0.2989 + img1[...,1]*0.5870 + img1[...,2]*0.1440
gr = gr.unsqueeze(-1)
plt.imshow(gr, cmap='gray')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-33-88fe98cdcad3> in <module>
#       2 gr = img1[...,0]*0.2989 + img1[...,1]*0.5870 + img1[...,2]*0.1440
#       3 gr = gr.unsqueeze(-1)
# ----> 4 plt.imshow(gr, cmap='gray')
#
# ~/bin/miniconda3/envs/videoai/lib/python3.8/site-packages/matplotlib-3.4.2-py3.8-linux-x86_64.egg/matplotlib/pyplot.py in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, filternorm, filterrad, resample, url, data, **kwargs)
#    2901         filternorm=True, filterrad=4.0, resample=None, url=None,
#    2902         data=None, **kwargs):
# -> 2903     __ret = gca().imshow(
#    2904         X, cmap=cmap, norm=norm, aspect=aspect,
#    2905         interpolation=interpolation, alpha=alpha, vmin=vmin,
#
# ...
